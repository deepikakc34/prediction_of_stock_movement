# %%
#from bs4 import BeautifulSoup
#import requests

#source = requests.get('https://twitter.com/search?vertical=default&amp;q=%23AAPL&amp;l=en&amp;src=unkn').text
#soup = BeautifulSoup(source, 'html.parser')

#parent = soup.find('main')
#print(soup)

# I COULDN'T FIND THE TAGS CONSISTING OF TWEETS WHICH IS VISIBLE WHEN WE INSPECT
# I COULD SEE THE TAGS, WHERE WE WOULD EXPECT TWEETS DATA, HAS MULTIPLE EMPTY TAGS
# COULD BE DUE TO ACCESS ISSUE, NEVERTHLESS MOVING AHEAD WITH SELENIUM
# Out:
# <!DOCTYPE html>
#
# <html data-scribe-reduced-action-queue="true" lang="en">
# <head>
# <meta charset="utf-8"/>
# <script nonce="BjyOBhONesDHF5Kgxr97zw==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="BjyOBhONesDHF5Kgxr97zw==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="BjyOBhONesDHF5Kgxr97zw==">
# ...

# %%
#from selenium import webdriver

#Access to Twitter
#url = r'https://twitter.com'
#driver = webdriver.Chrome()
#driver.get(url)

# AGAIN FACING ACCESS ISSUES
# Out:
# "from selenium import webdriver\n\n# Access to Twitter\nurl = r'https://twitter.com'\ndriver = webdriver.Chrome()\ndriver.get(url)"

# %%
#from twitterscraper import query_tweets
#import datetime
#import pandas

#begin = datetime.date(2020,4,18)
#end = datetime.date(2020,3,18)

#tweets = query_tweets('#AAPL', begindate = end, enddate = begin, limit = 1000, lang = 'english', poolsize = 20)
#print(tweets)
#df = pandas.DataFrame(tweets.__dict__ for t in tweets)
#df



#for tweet in query_tweets("#AAPL", 10)[:10]:
    #print(tweet.user.encode('utf-8'))
    
    
# WHEN I WAS RUNNING THIS CODE, THE OUTPUT NOTES SHOWED CERTAIN AMOUNT OF TWEETS BEING RETRIEVED
# SOON AFTER THE OUTPUT SHOWED ERROR IN RETRIEVING THE DATA WITH SIGNAL 11 ERROR, WASN'T ABLE TO RESOLVE
# Out:
# INFO: queries: ['#AAPL since:2020-03-18 until:2020-03-19', '#AAPL since:2020-03-19 until:2020-03-21', '#AAPL since:2020-03-21 until:2020-03-22', '#AAPL since:2020-03-22 until:2020-03-24', '#AAPL since:2020-03-24 until:2020-03-25', '#AAPL since:2020-03-25 until:2020-03-27', '#AAPL since:2020-03-27 until:2020-03-28', '#AAPL since:2020-03-28 until:2020-03-30', '#AAPL since:2020-03-30 until:2020-03-31', '#AAPL since:2020-03-31 until:2020-04-02', '#AAPL since:2020-04-02 until:2020-04-04', '#AAPL since:2020-04-04 until:2020-04-05', '#AAPL since:2020-04-05 until:2020-04-07', '#AAPL since:2020-04-07 until:2020-04-08', '#AAPL since:2020-04-08 until:2020-04-10', '#AAPL since:2020-04-10 until:2020-04-11', '#AAPL since:2020-04-11 until:2020-04-13', '#AAPL since:2020-04-13 until:2020-04-14', '#AAPL since:2020-04-14 until:2020-04-16', '#AAPL since:2020-04-16 until:2020-04-18']
# INFO: Querying #AAPL since:2020-03-18 until:2020-03-19
# INFO: Querying #AAPL since:2020-03-24 until:2020-03-25
# ...

# %%
# RUN THE BELOW COMMAND IN TERMINAL/COMMANDLINE, A JSON FILE WILL BE CREATED WITH REQUIRED TWEETS RETRIEVED
# twitterscraper '#AAPL' --begindate 2020-03-17 --enddate 2020-04-17 --lang en --poolsize 20 --output tweets.json

import json
import pandas

tweets = ''
with open('tweets.json') as twt:
    response = json.loads(twt.read())
    tweets = response
split = tweets
#print(split)
df = pandas.DataFrame(tweets)
df.to_csv(r'tweetson04192020_time1102am.csv', index = False)
